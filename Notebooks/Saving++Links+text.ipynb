# %%
link = "https://public.tableau.com/views/SalesPerfomanceDashboard_17743468240840/SalesPerformaceDashboard?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link"

with open("../Tableau Dashboard Link/Sales Perfomance Dashbaord.text" , "w") as file :
    file.write(link)

# %%
link1 = "https://www.kaggle.com/datasets/ulrikthygepedersen/online-retail-dataset"

with open("../Data/online_retail_data.text" , "w") as file :
    file.write(link1)
